# %%
import pandas as pd
from pathlib import Path

# %%
# Store filepath in a variable
housing_csv_path = Path("Resource/RDC_Inventory_Core_Metrics_County_History.csv")

# %%
# Read our data file with the Pandas library
df = pd.read_csv(housing_csv_path)

# %%
# Show the first five rows.
df.head()
# Out:
#    month_date_yyyymm  county_fips    county_name  median_listing_price  \
# 0             202410        18049     fulton, in              277500.0
# 1             202410        13027     brooks, ga              259900.0
# 2             202410        20171      scott, ks              307000.0
# 3             202410        25027  worcester, ma              546175.0
# 4             202410        18115       ohio, in              288650.0
#
#    median_listing_price_mm  median_listing_price_yy  active_listing_count  \
# 0                  -0.1175                   0.0282                  45.0
# 1                  -0.0048                   0.1631                  25.0
# 2                   0.2280                   0.5049                   3.0
# 3                   0.0116                   0.0762                1104.0
# 4                  -0.0503                  -0.3349                   9.0
#
#    active_listing_count_mm  active_listing_count_yy  median_days_on_market  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310177 entries, 0 to 310176
# Data columns (total 40 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   month_date_yyyymm                        310177 non-null  int64
#  1   county_fips                              310177 non-null  int64
#  2   county_name                              310177 non-null  object
#  3   median_listing_price                     310111 non-null  float64
#  4   median_listing_price_mm                  272704 non-null  float64
#  5   median_listing_price_yy                  271458 non-null  float64
#  6   active_listing_count                     310132 non-null  float64
#  7   active_listing_count_mm                  272639 non-null  float64
#  8   active_listing_count_yy                  271319 non-null  float64
#  9   median_days_on_market                    309807 non-null  float64
# ...

# %%
#Dropping columns that have empty cells over the 50% threshold.
threshold = 0.5
columns_to_drop = df.columns[df.isnull().mean() > threshold]
data_cleaned = df.drop(columns=columns_to_drop)
data_cleaned.head()
# Out:
#    month_date_yyyymm  county_fips    county_name  median_listing_price  \
# 0             202410        18049     fulton, in              277500.0
# 1             202410        13027     brooks, ga              259900.0
# 2             202410        20171      scott, ks              307000.0
# 3             202410        25027  worcester, ma              546175.0
# 4             202410        18115       ohio, in              288650.0
#
#    median_listing_price_mm  median_listing_price_yy  active_listing_count  \
# 0                  -0.1175                   0.0282                  45.0
# 1                  -0.0048                   0.1631                  25.0
# 2                   0.2280                   0.5049                   3.0
# 3                   0.0116                   0.0762                1104.0
# 4                  -0.0503                  -0.3349                   9.0
#
#    active_listing_count_mm  active_listing_count_yy  median_days_on_market  \
# ...

# %%
removed_columns = list(columns_to_drop)
removed_columns
# Out:
# ['price_increased_count_mm', 'price_increased_count_yy']

# %%
#only keeping rows where quality flag equals 0. If there was a quality flag it would have been an outlier where the home was overpriced or under priced. 
df_test = df[df['quality_flag'] != 1]
df_test.head(10)
# Out:
#     month_date_yyyymm  county_fips    county_name  median_listing_price  \
# 0              202410        18049     fulton, in              277500.0
# 1              202410        13027     brooks, ga              259900.0
# 3              202410        25027  worcester, ma              546175.0
# 5              202410        51183     sussex, va              313950.0
# 7              202410        53011      clark, wa              671725.0
# 8              202410        13197     marion, ga              356250.0
# 9              202410         8073    lincoln, co              324500.0
# 10             202410        48441     taylor, tx              269925.0
# 11             202410        26063      huron, mi              209950.0
# 13             202410        31025       cass, ne              395100.0
#
#     median_listing_price_mm  median_listing_price_yy  active_listing_count  \
# 0                   -0.1175                   0.0282                  45.0
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 221141 entries, 0 to 310176
# Data columns (total 40 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   month_date_yyyymm                        221141 non-null  int64
#  1   county_fips                              221141 non-null  int64
#  2   county_name                              221141 non-null  object
#  3   median_listing_price                     221084 non-null  float64
#  4   median_listing_price_mm                  183966 non-null  float64
#  5   median_listing_price_yy                  182440 non-null  float64
#  6   active_listing_count                     221096 non-null  float64
#  7   active_listing_count_mm                  183967 non-null  float64
#  8   active_listing_count_yy                  182430 non-null  float64
#  9   median_days_on_market                    220932 non-null  float64
# ...

# %%
#dropping columns that are not needed
cleaned_df= df_test.drop(['median_listing_price', 'median_listing_price_mm','median_listing_price_yy','new_listing_count_mm',
              'new_listing_count_yy','pending_ratio','pending_ratio_mm','pending_ratio_yy','pending_listing_count','pending_listing_count_mm',
             'pending_listing_count_yy','quality_flag'], axis=1)

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 221141 entries, 0 to 310176
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   month_date_yyyymm                        221141 non-null  int64
#  1   county_fips                              221141 non-null  int64
#  2   county_name                              221141 non-null  object
#  3   active_listing_count                     221096 non-null  float64
#  4   active_listing_count_mm                  183967 non-null  float64
#  5   active_listing_count_yy                  182430 non-null  float64
#  6   median_days_on_market                    220932 non-null  float64
#  7   median_days_on_market_mm                 183864 non-null  float64
#  8   median_days_on_market_yy                 182320 non-null  float64
#  9   new_listing_count                        221098 non-null  float64
# ...

# %%
cleaned_df
# Out:
#         month_date_yyyymm  county_fips    county_name  active_listing_count  \
# 0                  202410        18049     fulton, in                  45.0
# 1                  202410        13027     brooks, ga                  25.0
# 3                  202410        25027  worcester, ma                1104.0
# 5                  202410        51183     sussex, va                  18.0
# 7                  202410        53011      clark, wa                1474.0
# ...                   ...          ...            ...                   ...
# 310172             201607        20003   anderson, ks                  60.0
# 310173             201607         9013    tolland, ct                1021.0
# 310174             201607        49043     summit, ut                1094.0
# 310175             201607        51009    amherst, va                 184.0
# 310176             201607        21023    bracken, ky                  30.0
#
# ...

# %%
#Dropping rows with NaN values
df_cleaned = cleaned_df.dropna()
df_cleaned.head()
# Out:
#     month_date_yyyymm  county_fips     county_name  active_listing_count  \
# 3              202410        25027   worcester, ma                1104.0
# 7              202410        53011       clark, wa                1474.0
# 10             202410        48441      taylor, tx                 623.0
# 20             202410        39093      lorain, oh                 436.0
# 26             202410        37157  rockingham, nc                 215.0
#
#     active_listing_count_mm  active_listing_count_yy  median_days_on_market  \
# 3                    0.0755                   0.3826                   31.0
# 7                   -0.0277                   0.3475                   58.0
# 10                  -0.0341                   0.1833                   67.0
# 20                   0.0406                   0.1414                   42.0
# 26                   0.0617                   0.2836                   45.0
#
# ...

# %%
#Renaming columns for readability.
df_renamed = df_cleaned.rename(columns={"month_date_yyyymm": "Date YYYMM","county_fips": "County FIPS", "county_name":"County Name","active_listing_count":"Active Listing Count",
                                "active_listing_count_mm":"Active Listing Count M/M","active_listing_count_yy":"Active Listing Count Y/Y",
                                "median_days_on_market":"Median Days on Market","median_days_on_market_mm":"Median Days on Market M/M","median_days_on_market_yy":"Median Days on Market Y/Y",
                                "new_listing_count":"New Listing Count","price_increased_count":"Price Increase Count","price_increased_count_mm":"Price Increase Count M/M",
                                "price_increased_count_yy":"Price Increase Count Y/Y","price_reduced_count":"Price Decrease Count","price_reduced_count_mm":"Price Decrease Count M/M",
                                "price_reduced_count_yy":"Price Decrease Count Y/Y","median_listing_price_per_square_foot":"Median List Price Per Sqft",
                                "median_listing_price_per_square_foot_mm":"Median List Price Per Sqft M/M","median_listing_price_per_square_foot_yy":"Median List Price Per Sqft Y/Y",
                                "median_square_feet":"Median Sqft","median_square_feet_mm":"Median sqft M/M","median_square_feet_yy":"Median Sqft Y/Y",
                                "average_listing_price":"Avg Listing Price","average_listing_price_mm":"Avg Listing Price M/M","average_listing_price_yy":"Avg Listing Price Y/Y",
                                "total_listing_count":"Total Listing Count","total_listing_count_mm":"Total Listing Count M/M","total_listing_count_yy":"Total Listing Count Y/Y"})

# %%
df_renamed.head()
# Out:
#     Date YYYMM  County FIPS     County Name  Active Listing Count  \
# 3       202410        25027   worcester, ma                1104.0
# 7       202410        53011       clark, wa                1474.0
# 10      202410        48441      taylor, tx                 623.0
# 20      202410        39093      lorain, oh                 436.0
# 26      202410        37157  rockingham, nc                 215.0
#
#     Active Listing Count M/M  Active Listing Count Y/Y  Median Days on Market  \
# 3                     0.0755                    0.3826                   31.0
# 7                    -0.0277                    0.3475                   58.0
# 10                   -0.0341                    0.1833                   67.0
# 20                    0.0406                    0.1414                   42.0
# 26                    0.0617                    0.2836                   45.0
#
#     Median Days on Market M/M  Median Days on Market Y/Y  New Listing Count  \
# ...
