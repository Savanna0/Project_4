# %%
import pandas as pd
from pathlib import Path

# %%
# Store filepath in a variable
housing_csv_path = Path("Resources/RDC_Inventory_Core_Metrics_County_History.csv")

# %%
# Read our data file with the Pandas library
df = pd.read_csv(housing_csv_path)

# %%
# Show the first five rows.
df.head()
# Out:
#    month_date_yyyymm  county_fips    county_name  median_listing_price  \
# 0             202410        18049     fulton, in              277500.0
# 1             202410        13027     brooks, ga              259900.0
# 2             202410        20171      scott, ks              307000.0
# 3             202410        25027  worcester, ma              546175.0
# 4             202410        18115       ohio, in              288650.0
#
#    median_listing_price_mm  median_listing_price_yy  active_listing_count  \
# 0                  -0.1175                   0.0282                  45.0
# 1                  -0.0048                   0.1631                  25.0
# 2                   0.2280                   0.5049                   3.0
# 3                   0.0116                   0.0762                1104.0
# 4                  -0.0503                  -0.3349                   9.0
#
#    active_listing_count_mm  active_listing_count_yy  median_days_on_market  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310177 entries, 0 to 310176
# Data columns (total 40 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   month_date_yyyymm                        310177 non-null  int64
#  1   county_fips                              310177 non-null  int64
#  2   county_name                              310177 non-null  object
#  3   median_listing_price                     310111 non-null  float64
#  4   median_listing_price_mm                  272704 non-null  float64
#  5   median_listing_price_yy                  271458 non-null  float64
#  6   active_listing_count                     310132 non-null  float64
#  7   active_listing_count_mm                  272639 non-null  float64
#  8   active_listing_count_yy                  271319 non-null  float64
#  9   median_days_on_market                    309807 non-null  float64
# ...

# %%
#Dropping columns that have empty cells over the 50% threshold.
threshold = 0.5
columns_to_drop = df.columns[df.isnull().mean() > threshold]
data_cleaned = df.drop(columns=columns_to_drop)
data_cleaned.head()
# Out:
#    month_date_yyyymm  county_fips    county_name  median_listing_price  \
# 0             202410        18049     fulton, in              277500.0
# 1             202410        13027     brooks, ga              259900.0
# 2             202410        20171      scott, ks              307000.0
# 3             202410        25027  worcester, ma              546175.0
# 4             202410        18115       ohio, in              288650.0
#
#    median_listing_price_mm  median_listing_price_yy  active_listing_count  \
# 0                  -0.1175                   0.0282                  45.0
# 1                  -0.0048                   0.1631                  25.0
# 2                   0.2280                   0.5049                   3.0
# 3                   0.0116                   0.0762                1104.0
# 4                  -0.0503                  -0.3349                   9.0
#
#    active_listing_count_mm  active_listing_count_yy  median_days_on_market  \
# ...

# %%
removed_columns = list(columns_to_drop)
removed_columns
# Out:
# ['price_increased_count_mm', 'price_increased_count_yy']

# %%
#only keeping rows where quality flag equals 0. If there was a quality flag it would have been an outlier where the home was overpriced or under priced. 
df_test = df[df['quality_flag'] != 1]
df_test.head(10)
# Out:
#     month_date_yyyymm  county_fips    county_name  median_listing_price  \
# 0              202410        18049     fulton, in              277500.0
# 1              202410        13027     brooks, ga              259900.0
# 3              202410        25027  worcester, ma              546175.0
# 5              202410        51183     sussex, va              313950.0
# 7              202410        53011      clark, wa              671725.0
# 8              202410        13197     marion, ga              356250.0
# 9              202410         8073    lincoln, co              324500.0
# 10             202410        48441     taylor, tx              269925.0
# 11             202410        26063      huron, mi              209950.0
# 13             202410        31025       cass, ne              395100.0
#
#     median_listing_price_mm  median_listing_price_yy  active_listing_count  \
# 0                   -0.1175                   0.0282                  45.0
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 221141 entries, 0 to 310176
# Data columns (total 40 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   month_date_yyyymm                        221141 non-null  int64
#  1   county_fips                              221141 non-null  int64
#  2   county_name                              221141 non-null  object
#  3   median_listing_price                     221084 non-null  float64
#  4   median_listing_price_mm                  183966 non-null  float64
#  5   median_listing_price_yy                  182440 non-null  float64
#  6   active_listing_count                     221096 non-null  float64
#  7   active_listing_count_mm                  183967 non-null  float64
#  8   active_listing_count_yy                  182430 non-null  float64
#  9   median_days_on_market                    220932 non-null  float64
# ...

# %%
#dropping columns that are not needed
cleaned_df= df_test.drop(['median_listing_price', 'median_listing_price_mm','median_listing_price_yy','new_listing_count_mm',
              'new_listing_count_yy','pending_ratio','pending_ratio_mm','pending_ratio_yy','pending_listing_count','pending_listing_count_mm',
              'pending_listing_count_yy','quality_flag','median_listing_price_mm','median_listing_price_yy','active_listing_count_mm','active_listing_count_yy',
              'median_days_on_market_mm','median_days_on_market_yy','new_listing_count_mm','new_listing_count_yy','price_increased_count_mm',
              'price_increased_count','price_increased_count_yy','price_reduced_count','price_reduced_count_mm','price_reduced_count_mm',
              'price_reduced_count_yy','median_listing_price_per_square_foot_mm','median_listing_price_per_square_foot_yy','median_square_feet_mm',
              'median_square_feet_yy','average_listing_price_mm','average_listing_price_yy','total_listing_count_mm','total_listing_count_yy',
              'pending_ratio_mm','pending_ratio_yy','county_fips'], axis=1)

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 221141 entries, 0 to 310176
# Data columns (total 9 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   month_date_yyyymm                     221141 non-null  int64
#  1   county_name                           221141 non-null  object
#  2   active_listing_count                  221096 non-null  float64
#  3   median_days_on_market                 220932 non-null  float64
#  4   new_listing_count                     221098 non-null  float64
#  5   median_listing_price_per_square_foot  220912 non-null  float64
#  6   median_square_feet                    220916 non-null  float64
#  7   average_listing_price                 221084 non-null  float64
#  8   total_listing_count                   221098 non-null  float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 16.9+ MB

# %%
cleaned_df
# Out:
#         month_date_yyyymm    county_name  active_listing_count  \
# 0                  202410     fulton, in                  45.0
# 1                  202410     brooks, ga                  25.0
# 3                  202410  worcester, ma                1104.0
# 5                  202410     sussex, va                  18.0
# 7                  202410      clark, wa                1474.0
# ...                   ...            ...                   ...
# 310172             201607   anderson, ks                  60.0
# 310173             201607    tolland, ct                1021.0
# 310174             201607     summit, ut                1094.0
# 310175             201607    amherst, va                 184.0
# 310176             201607    bracken, ky                  30.0
#
#         median_days_on_market  new_listing_count  \
# 0                        54.0               14.0
# 1                        60.0                4.0
# 3                        31.0              874.0
# ...

# %%
#Dropping rows with NaN values
df_cleaned = cleaned_df.dropna()
df_cleaned.head()
# Out:
#    month_date_yyyymm    county_name  active_listing_count  \
# 0             202410     fulton, in                  45.0
# 1             202410     brooks, ga                  25.0
# 3             202410  worcester, ma                1104.0
# 5             202410     sussex, va                  18.0
# 7             202410      clark, wa                1474.0
#
#    median_days_on_market  new_listing_count  \
# 0                   54.0               14.0
# 1                   60.0                4.0
# 3                   31.0              874.0
# 5                   28.0                8.0
# 7                   58.0              604.0
#
#    median_listing_price_per_square_foot  median_square_feet  \
# 0                                 146.0              2102.0
# 1                                 139.0              1729.0
# 3                                 286.0              1985.0
# 5                                 169.0              1764.0
# ...

# %%
#Renaming columns for readability.
df_renamed = df_cleaned.rename(columns={"month_date_yyyymm": "Date YYYYMM","county_fips": "County FIPS", "county_name":"County Name","active_listing_count":"Active Listing Count",
                                "active_listing_count_mm":"Active Listing Count M/M","active_listing_count_yy":"Active Listing Count Y/Y",
                                "median_days_on_market":"Median Days on Market","median_days_on_market_mm":"Median Days on Market M/M","median_days_on_market_yy":"Median Days on Market Y/Y",
                                "new_listing_count":"New Listing Count","price_increased_count":"Price Increase Count","price_increased_count_mm":"Price Increase Count M/M",
                                "price_increased_count_yy":"Price Increase Count Y/Y","price_reduced_count":"Price Decrease Count","price_reduced_count_mm":"Price Decrease Count M/M",
                                "price_reduced_count_yy":"Price Decrease Count Y/Y","median_listing_price_per_square_foot":"Median List Price Per Sqft",
                                "median_listing_price_per_square_foot_mm":"Median List Price Per Sqft M/M","median_listing_price_per_square_foot_yy":"Median List Price Per Sqft Y/Y",
                                "median_square_feet":"Median Sqft","median_square_feet_mm":"Median sqft M/M","median_square_feet_yy":"Median Sqft Y/Y",
                                "average_listing_price":"Avg Listing Price","average_listing_price_mm":"Avg Listing Price M/M","average_listing_price_yy":"Avg Listing Price Y/Y",
                                "total_listing_count":"Total Listing Count","total_listing_count_mm":"Total Listing Count M/M","total_listing_count_yy":"Total Listing Count Y/Y"})

# %%
df_renamed.head()
# Out:
#    Date YYYYMM    County Name  Active Listing Count  Median Days on Market  \
# 0       202410     fulton, in                  45.0                   54.0
# 1       202410     brooks, ga                  25.0                   60.0
# 3       202410  worcester, ma                1104.0                   31.0
# 5       202410     sussex, va                  18.0                   28.0
# 7       202410      clark, wa                1474.0                   58.0
#
#    New Listing Count  Median List Price Per Sqft  Median Sqft  \
# 0               14.0                       146.0       2102.0
# 1                4.0                       139.0       1729.0
# 3              874.0                       286.0       1985.0
# 5                8.0                       169.0       1764.0
# 7              604.0                       309.0       2225.0
#
#    Avg Listing Price  Total Listing Count
# 0           363246.0                 61.0
# 1           295232.0                 26.0
# ...

# %%
#df_renamed['Year'] = df_renamed['Date YYYYMM'].str[:4].astype(int)
#df_renamed['Month'] = df_renamed['Date YYYYMM'].str[4:].astype(int)

df_renamed['Year'] = df_renamed['Date YYYYMM'].astype(str).str[:4].astype(int)  # Convert the year to integer
df_renamed['Month'] = df_renamed['Date YYYYMM'].astype(str).str[4:6].astype(int)  # Convert the month to integer

# %%
df_renamed
# Out:
#         Date YYYYMM    County Name  Active Listing Count  \
# 0            202410     fulton, in                  45.0
# 1            202410     brooks, ga                  25.0
# 3            202410  worcester, ma                1104.0
# 5            202410     sussex, va                  18.0
# 7            202410      clark, wa                1474.0
# ...             ...            ...                   ...
# 310172       201607   anderson, ks                  60.0
# 310173       201607    tolland, ct                1021.0
# 310174       201607     summit, ut                1094.0
# 310175       201607    amherst, va                 184.0
# 310176       201607    bracken, ky                  30.0
#
#         Median Days on Market  New Listing Count  Median List Price Per Sqft  \
# 0                        54.0               14.0                       146.0
# 1                        60.0                4.0                       139.0
# ...

# %%
new_df= df_renamed.drop(['Date YYYYMM'], axis=1)
new_df
# Out:
#           County Name  Active Listing Count  Median Days on Market  \
# 0          fulton, in                  45.0                   54.0
# 1          brooks, ga                  25.0                   60.0
# 3       worcester, ma                1104.0                   31.0
# 5          sussex, va                  18.0                   28.0
# 7           clark, wa                1474.0                   58.0
# ...               ...                   ...                    ...
# 310172   anderson, ks                  60.0                  111.0
# 310173    tolland, ct                1021.0                   64.0
# 310174     summit, ut                1094.0                   68.0
# 310175    amherst, va                 184.0                   73.0
# 310176    bracken, ky                  30.0                  114.0
#
#         New Listing Count  Median List Price Per Sqft  Median Sqft  \
# 0                    14.0                       146.0       2102.0
# ...

# %%
column_names = new_df.columns.tolist()
print(column_names)
# Out:
# ['County Name', 'Active Listing Count', 'Median Days on Market', 'New Listing Count', 'Median List Price Per Sqft', 'Median Sqft', 'Avg Listing Price', 'Total Listing Count', 'Year', 'Month']

# %%
# Reorder columns
df_reordered = new_df[['Year', 'Month', 'County Name', 'Active Listing Count','Median Days on Market',
                   'New Listing Count','Median List Price Per Sqft','Median Sqft','Avg Listing Price','Total Listing Count',
                   ]]

df_reordered
# Out:
#         Year  Month    County Name  Active Listing Count  \
# 0       2024     10     fulton, in                  45.0
# 1       2024     10     brooks, ga                  25.0
# 3       2024     10  worcester, ma                1104.0
# 5       2024     10     sussex, va                  18.0
# 7       2024     10      clark, wa                1474.0
# ...      ...    ...            ...                   ...
# 310172  2016      7   anderson, ks                  60.0
# 310173  2016      7    tolland, ct                1021.0
# 310174  2016      7     summit, ut                1094.0
# 310175  2016      7    amherst, va                 184.0
# 310176  2016      7    bracken, ky                  30.0
#
#         Median Days on Market  New Listing Count  Median List Price Per Sqft  \
# 0                        54.0               14.0                       146.0
# 1                        60.0                4.0                       139.0
# ...

# %%
df_reordered = df_reordered.reset_index(drop=True)
df_reordered.index.name = 'Index'
df_reordered
# Out:
#         Year  Month    County Name  Active Listing Count  \
# Index
# 0       2024     10     fulton, in                  45.0
# 1       2024     10     brooks, ga                  25.0
# 2       2024     10  worcester, ma                1104.0
# 3       2024     10     sussex, va                  18.0
# 4       2024     10      clark, wa                1474.0
# ...      ...    ...            ...                   ...
# 220761  2016      7   anderson, ks                  60.0
# 220762  2016      7    tolland, ct                1021.0
# 220763  2016      7     summit, ut                1094.0
# 220764  2016      7    amherst, va                 184.0
# 220765  2016      7    bracken, ky                  30.0
#
#         Median Days on Market  New Listing Count  Median List Price Per Sqft  \
# Index
# 0                        54.0               14.0                       146.0
# 1                        60.0                4.0                       139.0
# ...

# %%
#after 3rd normal form and ERD
# Load the DataFrame into the database
#df.to_sql('table_name', con=engine, if_exists='replace', index=False)
#Session = sessionmaker(bind=engine)
#session = Session()

# %%
#no csv
df_reordered.to_csv('Resources/cleaned_housing_market_data.csv', sep=',', index=True)

# %%
#Split County Name Column
df_county_split = df_reordered.copy()

df_county_split['County Name'].str.split(',', expand = True)
df_county_split[['County', 'State']] = df_county_split['County Name'].str.split(',', expand=True)

df_county_split
# Out:
#         Year  Month    County Name  Active Listing Count  \
# Index
# 0       2024     10     fulton, in                  45.0
# 1       2024     10     brooks, ga                  25.0
# 2       2024     10  worcester, ma                1104.0
# 3       2024     10     sussex, va                  18.0
# 4       2024     10      clark, wa                1474.0
# ...      ...    ...            ...                   ...
# 220761  2016      7   anderson, ks                  60.0
# 220762  2016      7    tolland, ct                1021.0
# 220763  2016      7     summit, ut                1094.0
# 220764  2016      7    amherst, va                 184.0
# 220765  2016      7    bracken, ky                  30.0
#
#         Median Days on Market  New Listing Count  Median List Price Per Sqft  \
# Index
# 0                        54.0               14.0                       146.0
# 1                        60.0                4.0                       139.0
# ...

# %%
# Drop County Name column
df_county_drop= df_county_split.drop(['County Name', 'County'], axis=1)
df_county_drop.head()
# Out:
#        Year  Month  Active Listing Count  Median Days on Market  \
# Index
# 0      2024     10                  45.0                   54.0
# 1      2024     10                  25.0                   60.0
# 2      2024     10                1104.0                   31.0
# 3      2024     10                  18.0                   28.0
# 4      2024     10                1474.0                   58.0
#
#        New Listing Count  Median List Price Per Sqft  Median Sqft  \
# Index
# 0                   14.0                       146.0       2102.0
# 1                    4.0                       139.0       1729.0
# 2                  874.0                       286.0       1985.0
# 3                    8.0                       169.0       1764.0
# 4                  604.0                       309.0       2225.0
#
#        Avg Listing Price  Total Listing Count State
# Index
# 0               363246.0                 61.0    in
# 1               295232.0                 26.0    ga
# ...

# %%
# Reorder County Dataframe
df_state = df_county_drop[[ 'Year', 'Month', 'State', 'Active Listing Count','Median Days on Market',
                   'New Listing Count','Median List Price Per Sqft','Median Sqft','Avg Listing Price','Total Listing Count',
                   ]]
df_state
# Out:
#         Year  Month State  Active Listing Count  Median Days on Market  \
# Index
# 0       2024     10    in                  45.0                   54.0
# 1       2024     10    ga                  25.0                   60.0
# 2       2024     10    ma                1104.0                   31.0
# 3       2024     10    va                  18.0                   28.0
# 4       2024     10    wa                1474.0                   58.0
# ...      ...    ...   ...                   ...                    ...
# 220761  2016      7    ks                  60.0                  111.0
# 220762  2016      7    ct                1021.0                   64.0
# 220763  2016      7    ut                1094.0                   68.0
# 220764  2016      7    va                 184.0                   73.0
# 220765  2016      7    ky                  30.0                  114.0
#
#         New Listing Count  Median List Price Per Sqft  Median Sqft  \
# Index
# ...

# %%
#Export to csv
df_state.to_csv('Resources/df_state.csv', sep=',', index=True)

# %%
#Create copy for attempt 3
df_opt_3 = df_state.copy()
df_opt_3.head()
# Out:
#        Year  Month State  Active Listing Count  Median Days on Market  \
# Index
# 0      2024     10    in                  45.0                   54.0
# 1      2024     10    ga                  25.0                   60.0
# 2      2024     10    ma                1104.0                   31.0
# 3      2024     10    va                  18.0                   28.0
# 4      2024     10    wa                1474.0                   58.0
#
#        New Listing Count  Median List Price Per Sqft  Median Sqft  \
# Index
# 0                   14.0                       146.0       2102.0
# 1                    4.0                       139.0       1729.0
# 2                  874.0                       286.0       1985.0
# 3                    8.0                       169.0       1764.0
# 4                  604.0                       309.0       2225.0
#
#        Avg Listing Price  Total Listing Count
# Index
# 0               363246.0                 61.0
# ...

# %%
more_columns = df_test.copy()
more_columns.head()
# Out:
#    month_date_yyyymm  county_fips    county_name  median_listing_price  \
# 0             202410        18049     fulton, in              277500.0
# 1             202410        13027     brooks, ga              259900.0
# 3             202410        25027  worcester, ma              546175.0
# 5             202410        51183     sussex, va              313950.0
# 7             202410        53011      clark, wa              671725.0
#
#    median_listing_price_mm  median_listing_price_yy  active_listing_count  \
# 0                  -0.1175                   0.0282                  45.0
# 1                  -0.0048                   0.1631                  25.0
# 3                   0.0116                   0.0762                1104.0
# 5                   0.2439                   0.3087                  18.0
# 7                   0.0216                   0.0213                1474.0
#
#    active_listing_count_mm  active_listing_count_yy  median_days_on_market  \
# ...

# %%
#Dropping columns that are not needed
df_copy = more_columns.drop(['month_date_yyyymm', 'county_name', 'new_listing_count', 'active_listing_count', 'median_days_on_market',
              'median_listing_price_per_square_foot', 'median_square_feet', 'average_listing_price', 'total_listing_count',
              'median_listing_price_mm','median_listing_price_yy','new_listing_count_mm', 'new_listing_count_yy','pending_ratio',
              'pending_ratio_mm','pending_ratio_yy','pending_listing_count','pending_listing_count_mm','pending_listing_count_yy',
              'quality_flag','median_listing_price_mm','median_listing_price_yy','active_listing_count_mm','active_listing_count_yy',
              'median_days_on_market_mm','median_days_on_market_yy','new_listing_count_mm','new_listing_count_yy','price_increased_count_mm',
              'price_increased_count_yy','price_reduced_count_mm','price_reduced_count_mm', 'price_reduced_count_yy',
              'median_listing_price_per_square_foot_mm','median_listing_price_per_square_foot_yy','median_square_feet_mm',
              'median_square_feet_yy','average_listing_price_mm','average_listing_price_yy','total_listing_count_mm','total_listing_count_yy',
              'pending_ratio_mm','pending_ratio_yy','county_fips'], axis=1)

df_copy.head()
# Out:
#    median_listing_price  price_increased_count  price_reduced_count
# 0              277500.0                    0.0                 14.0
# 1              259900.0                    0.0                  4.0
# 3              546175.0                   20.0                462.0
# 5              313950.0                    0.0                  8.0
# 7              671725.0                  212.0                794.0

# %%
#Dropping rows with NaN values
df_copy_cleaned = df_copy.dropna()
df_copy_cleaned
# Out:
#         median_listing_price  price_increased_count  price_reduced_count
# 0                   277500.0                    0.0                 14.0
# 1                   259900.0                    0.0                  4.0
# 3                   546175.0                   20.0                462.0
# 5                   313950.0                    0.0                  8.0
# 7                   671725.0                  212.0                794.0
# ...                      ...                    ...                  ...
# 310172               88800.0                    0.0                  4.0
# 310173              264950.0                    8.0                268.0
# 310174             1115000.0                   24.0                152.0
# 310175              188200.0                    0.0                 28.0
# 310176              110000.0                    0.0                  0.0
#
# [221084 rows x 3 columns]

# %%
#Renaming columns for readability.
df_renamed_2 = df_copy_cleaned.rename(columns={"median_listing_price":"Median Listing Price", "price_increased_count": "Price Increased Count",
                                               "price_reduced_count": "Price Reduced Count"})

df_renamed_2.head()
# Out:
#    Median Listing Price  Price Increased Count  Price Reduced Count
# 0              277500.0                    0.0                 14.0
# 1              259900.0                    0.0                  4.0
# 3              546175.0                   20.0                462.0
# 5              313950.0                    0.0                  8.0
# 7              671725.0                  212.0                794.0

# %%
opt_3_data = pd.concat([df_state, df_renamed_2], axis=1)
opt_3_data.head()
# Out:
#      Year  Month State  Active Listing Count  Median Days on Market  \
# 0  2024.0   10.0    in                  45.0                   54.0
# 1  2024.0   10.0    ga                  25.0                   60.0
# 2  2024.0   10.0    ma                1104.0                   31.0
# 3  2024.0   10.0    va                  18.0                   28.0
# 4  2024.0   10.0    wa                1474.0                   58.0
#
#    New Listing Count  Median List Price Per Sqft  Median Sqft  \
# 0               14.0                       146.0       2102.0
# 1                4.0                       139.0       1729.0
# 2              874.0                       286.0       1985.0
# 3                8.0                       169.0       1764.0
# 4              604.0                       309.0       2225.0
#
#    Avg Listing Price  Total Listing Count  Median Listing Price  \
# 0           363246.0                 61.0              277500.0
# ...

# %%
opt_3_data_cleaned = opt_3_data.dropna()
opt_3_data_cleaned
# Out:
#           Year  Month State  Active Listing Count  Median Days on Market  \
# 0       2024.0   10.0    in                  45.0                   54.0
# 1       2024.0   10.0    ga                  25.0                   60.0
# 3       2024.0   10.0    va                  18.0                   28.0
# 5       2024.0   10.0    ga                   9.0                   46.0
# 7       2024.0   10.0    tx                 623.0                   67.0
# ...        ...    ...   ...                   ...                    ...
# 220761  2016.0    7.0    ks                  60.0                  111.0
# 220762  2016.0    7.0    ct                1021.0                   64.0
# 220763  2016.0    7.0    ut                1094.0                   68.0
# 220764  2016.0    7.0    va                 184.0                   73.0
# 220765  2016.0    7.0    ky                  30.0                  114.0
#
#         New Listing Count  Median List Price Per Sqft  Median Sqft  \
# ...

# %%
opt_3_df_final = opt_3_data_cleaned.reset_index(drop=True)
opt_3_df_final.index.name = 'Index'
opt_3_df_final
# Out:
#           Year  Month State  Active Listing Count  Median Days on Market  \
# Index
# 0       2024.0   10.0    in                  45.0                   54.0
# 1       2024.0   10.0    ga                  25.0                   60.0
# 2       2024.0   10.0    va                  18.0                   28.0
# 3       2024.0   10.0    ga                   9.0                   46.0
# 4       2024.0   10.0    tx                 623.0                   67.0
# ...        ...    ...   ...                   ...                    ...
# 144671  2016.0    7.0    ks                  60.0                  111.0
# 144672  2016.0    7.0    ct                1021.0                   64.0
# 144673  2016.0    7.0    ut                1094.0                   68.0
# 144674  2016.0    7.0    va                 184.0                   73.0
# 144675  2016.0    7.0    ky                  30.0                  114.0
#
#         New Listing Count  Median List Price Per Sqft  Median Sqft  \
# Index
# ...

# %%
# Export csv
opt_3_df_final.to_csv('Resources/opt_3.csv', sep=',', index=True)
